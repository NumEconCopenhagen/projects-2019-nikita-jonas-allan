# %% [markdown]
# # Analysis of Danish GDP and Phillips curve
# Our data project uses data imported from Statistics Denmark. We import data about the Danish Gross Domestic Product (GDP) in per capita current prices (1000 DKK) and 2010-prices chained values (1000 DKK). Further, we download information for Danish inflation and unemployment statistics. This we have done in order to make a Danish Phillips curve.
#
# # Import of relevant packages
#  Before we can begin our analysis, we start start our project by improting relevant packages. This includes pandas, numpy matplot lib and plotly. The last one will be usefull for when we will make interactive plots
# Last package we import, is package from "Danmarks Statistik", so we can import relevant statistics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pydst
dst = pydst.Dst(lang = 'da')
from ipywidgets import widgets, interactive

# %% [markdown]
# # Examination of Danish GDP per capita
#
# After importing relevant packages, we redefine columns that are used in DST, so they have english names. On top of that, this will help us choosing relevant columns when we make our tables

# %%
columns_dict = {}
columns_dict['TRANSAKT'] = 'variable'
columns_dict['PRISENHED'] = 'unit'
columns_dict['TID'] = 'year'
columns_dict['INDHOLD'] = 'value'
columns_dict['HOVED'] = 'Type'
columns_dict['PERPCT'] = 'Type'

# %% [markdown]
# Now we define the individual, relevant, variables from DST columns

# %%
var_dict = {} # var is for variable

#VARIABLES
var_dict['B.1*g Bruttonationalprodukt, BNP'] = 'Y'
var_dict['P.31 Privatforbrug'] = 'C'
var_dict['P.3 Offentlige forbrugsudgifter'] = 'G'
var_dict['P.5g Bruttoinvesteringer'] = 'I'
var_dict['P.6 Eksport af varer og tjenester'] = 'X'
var_dict['P.7 Import af varer og tjenester'] = 'M'
var_dict['ÅRSSTIGNING'] = 'Inflation'

#UNITS
unit_dict = {}
unit_dict['2010-priser, kædede værdier'] = 'realle'
unit_dict['løbende priser'] = 'nominelle'

# %% [markdown]
# Next section we define a variable "NAN1". This variable is a matrix of variables 'TRANSAKT', 'PRISENHED' and 'TID'. The individual variables will then be renamed to our specified var-name from columns_dict.

# %%
#CODE
nan1 = dst.get_data(table_id = 'NAN1', variables={'TRANSAKT':['*'], 'PRISENHED':['*'], 'TID':['*']})
nan1.rename(columns = columns_dict, inplace = True)

for key,value in var_dict.items():
    nan1.variable.replace(key,value,inplace=True)

for key,value in unit_dict.items():
    nan1.unit.replace(key,value, inplace=True)

I = False
for key,value in var_dict.items():
    I = I | (nan1.variable == value)
nan1 = nan1[I]

# %% [markdown]
# We now make a variable 'X'. This variable removes all years prior to 2001. We use nan1=nan1[X] to make sure that from now un the dataset nan1 have all the newest values. Further, we make 2 other nan values, which will be usefull later in our project.
#
# Last line in the following section makes a new variable, which only selects the unit 'Pr. indbygger, løbende priser, (1000 kr.)', which is current prices per capita.

# %%
X = nan1["year"]>2000 
nan1 = nan1[X]
nan2=nan1
nan3=nan1

Y=nan1["unit"]=="Pr. indbygger, løbende priser, (1000 kr.)"

# %% [markdown]
# In the next section, we will select a different unit, this time 'Pr. indbygger, 2010- priser, kædede vædier, (1000 kr.)', which is our chained prices per. capita. The suffix _K indicates that its chained values.
# At the end, we sort our values first by year and then by variable (in assending order).
# Last note, we make sure that our data is in dataFrame

# %%
nan1 = nan1[Y]
df=pd.DataFrame(data=nan1)
df.sort_values(by=["year","variable"])


X = nan2["year"]>2000
nan2 = nan2[X]
Y=nan2["unit"]=="Pr. indbygger, 2010-priser, kædede værdier, (1000 kr.)"
nan2 = nan2[Y]
df_K=pd.DataFrame(data=nan2)
df_K.sort_values(by=["year","variable"])
# Out:
#      variable                                               unit  year  value
# 4130        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2001  140,8
# 4124        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2001   78,4
# 4184        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2001   64,0
# 4256        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2001  104,9
# 4238        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2001  134,5
# 3663        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2001  315,6
# 4316        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2002  142,4
# 4310        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2002   79,8
# 4370        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2002   63,0
# 4442        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2002  111,2
# 4424        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2002  139,8
# 4292        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2002  316,0
# 4502        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2003  143,9
# 4496        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2003   79,8
# 5005        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2003   62,5
# 5077        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2003  109,8
# 5059        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2003  137,8
# 4478        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2003  316,5
# 5137        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2004  150,2
# 5131        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2004   80,8
# 5191        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2004   66,5
# 5263        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2004  117,3
# 5245        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2004  141,6
# 5113        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2004  324,1
# 5323        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2005  155,3
# 5317        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2005   81,5
# 5377        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2005   70,0
# 5895        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2005  130,2
# 5877        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2005  152,1
# 5299        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2005  330,7
# ...       ...                                                ...   ...    ...
# 8774        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2014  155,8
# 8768        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2014   89,5
# 8828        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2014   67,5
# 8900        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2014  162,7
# 8882        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2014  184,2
# 8750        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2014  334,3
# 8960        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2015  158,3
# 8954        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2015   90,4
# 9461        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2015   70,5
# 9533        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2015  168,9
# 9515        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2015  189,5
# 8936        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2015  339,8
# 9593        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2016  160,3
# 9587        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2016   89,8
# 9647        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2016   74,3
# 9719        M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2016  174,7
# 9701        X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2016  195,3
# 9569        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2016  345,1
# 9779        C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2017  162,6
# 9773        G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2017   89,9
# 9833        I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2017   76,8
# 492         M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2017  179,7
# 474         X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2017  200,9
# 9755        Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2017  350,6
# 552         C  Pr. indbygger, 2010-priser, kædede værdier, (1...  2018  165,5
# 546         G  Pr. indbygger, 2010-priser, kædede værdier, (1...  2018   90,2
# 606         I  Pr. indbygger, 2010-priser, kædede værdier, (1...  2018   80,4
# 678         M  Pr. indbygger, 2010-priser, kædede værdier, (1...  2018  183,7
# 660         X  Pr. indbygger, 2010-priser, kædede værdier, (1...  2018  201,2
# 528         Y  Pr. indbygger, 2010-priser, kædede værdier, (1...  2018  353,9
#
# [108 rows x 4 columns]

# %% [markdown]
# We make new data frame for real growth. Suffix _Y indicates real growth in GDP (Y)

# %%
X = nan3["year"]>2000
nan3 = nan3[X]
bb=nan3["variable"]=="Y"
nan3 = nan3[bb]
Y=nan3["unit"]=="Realvækst i pct. i forhold til foregående periode"
nan3 = nan3[Y]
df_Y=pd.DataFrame(data=nan3)
df_Y.sort_values(by=["year","variable"])
# Out:
#      variable                                               unit  year value
# 3665        Y  Realvækst i pct. i forhold til foregående periode  2001   0,8
# 4294        Y  Realvækst i pct. i forhold til foregående periode  2002   0,5
# 4480        Y  Realvækst i pct. i forhold til foregående periode  2003   0,4
# 5115        Y  Realvækst i pct. i forhold til foregående periode  2004   2,7
# 5301        Y  Realvækst i pct. i forhold til foregående periode  2005   2,3
# 5933        Y  Realvækst i pct. i forhold til foregående periode  2006   3,9
# 6119        Y  Realvækst i pct. i forhold til foregående periode  2007   0,9
# 6749        Y  Realvækst i pct. i forhold til foregående periode  2008  -0,5
# 6935        Y  Realvækst i pct. i forhold til foregående periode  2009  -4,9
# 7121        Y  Realvækst i pct. i forhold til foregående periode  2010   1,9
# 7752        Y  Realvækst i pct. i forhold til foregående periode  2011   1,3
# 7938        Y  Realvækst i pct. i forhold til foregående periode  2012   0,2
# 8566        Y  Realvækst i pct. i forhold til foregående periode  2013   0,9
# 8752        Y  Realvækst i pct. i forhold til foregående periode  2014   1,6
# 8938        Y  Realvækst i pct. i forhold til foregående periode  2015   2,3
# 9571        Y  Realvækst i pct. i forhold til foregående periode  2016   2,4
# 9757        Y  Realvækst i pct. i forhold til foregående periode  2017   2,3
# 530         Y  Realvækst i pct. i forhold til foregående periode  2018   1,4

# %% [markdown]
# The next two sections, we make a new index, our year. Then we sort by this index, make sure that our comma values have the correct decimal (dot instead of comma) and we make a new collumn which is our net export

# %%
df.set_index(['year'], inplace=True)
df.sort_index(inplace=True)

# %%
df["value"]=df["value"].str.replace(",",".").astype(float)

NX = pd.to_numeric(df.loc[:,:].value[df.loc[:,:].variable == "X" ]) - pd.to_numeric(df.loc[:,:].value[df.loc[:,:].variable == "M" ])
NX.columns=["year","value"]

# %% [markdown]
# We now remake our table in such a way, so Net export is added, while export and import are removed. There is an error message which have no effect on our project. We tried to fix it, but could not do so without breaking our code

# %%
NX=pd.DataFrame(data=NX)

NX["variable"] ="NX"


dollo= pd.concat([df, NX])

dollo.sort_index(inplace=True)
dollo=dollo[dollo.variable !='X']
dollo=dollo[dollo.variable !='M']
dollo.sort_values(by=["year","variable"])
dollo.variable[dollo.variable == 'Y'] = "Y_L"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %% [markdown]
#  We make a GDP variable.

# %%
Y = pd.to_numeric(dollo.loc[:,:].value[dollo.loc[:,:].variable == 'C']) + pd.to_numeric(dollo.loc[:,:].value[dollo.loc[:,:].variable== 'G']) + pd.to_numeric(dollo.loc[:,:].value[dollo.loc[:,:].variable== 'I'])  + pd.to_numeric(dollo.loc[:,:].value[dollo.loc[:,:].variable== 'NX'])
Y.columns=['year','value']

# %% [markdown]
# We make a new data frame, for the total GDP, with year as index.

# %%
Y = pd.DataFrame(data=Y)
Y['variable'] = 'Y'

# %% [markdown]
# In the next section, we make chained value variables. Here we make year as index for our chained values and then sort by said index. After we have done this, we replace comma with punctuation and tranform our variable form string to float. In the end we make a new variable "Net Export" in chained values.

# %%
df_K.set_index(['year'], inplace=True)

df_K["value"]=df_K["value"].str.replace(",",".").astype(float)
df_K.sort_index(inplace=True)
NX_K = pd.to_numeric(df_K.loc[:,:].value[df_K.loc[:,:].variable == "X" ]) - pd.to_numeric(df_K.loc[:,:].value[df_K.loc[:,:].variable == "M" ])
NX_K.columns=["year","value"]

# %% [markdown]
# We remake Net export in chained values as a DataFrame and hereafter we adde NX_K into our collumn 'variable' as 'NX'. We make use of 'concat' to make a new list dollo_K.

# %%
NX_K=pd.DataFrame(data=NX_K)

NX_K["variable"] ="NX"

dollo_K= pd.concat([df_K, NX_K])
dollo_K.sort_index(inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %% [markdown]
# From the list 'dollo_K' we remove variables 'X' (Export), 'M' (Import) and 'Y' (GDP). We sort by year first and then by type of variable.

# %%
dollo_K=dollo_K[dollo_K.variable !='X']
dollo_K=dollo_K[dollo_K.variable !='M']
dollo_K=dollo_K[dollo_K.variable !='Y']
dollo_K.sort_values(by=["year","variable"])
# Out:
#                                                    unit  value variable
# year
# 2001  Pr. indbygger, 2010-priser, kædede værdier, (1...  140.8        C
# 2001  Pr. indbygger, 2010-priser, kædede værdier, (1...   78.4        G
# 2001  Pr. indbygger, 2010-priser, kædede værdier, (1...   64.0        I
# 2001                                                NaN   29.6       NX
# 2002  Pr. indbygger, 2010-priser, kædede værdier, (1...  142.4        C
# 2002  Pr. indbygger, 2010-priser, kædede værdier, (1...   79.8        G
# 2002  Pr. indbygger, 2010-priser, kædede værdier, (1...   63.0        I
# 2002                                                NaN   28.6       NX
# 2003  Pr. indbygger, 2010-priser, kædede værdier, (1...  143.9        C
# 2003  Pr. indbygger, 2010-priser, kædede værdier, (1...   79.8        G
# 2003  Pr. indbygger, 2010-priser, kædede værdier, (1...   62.5        I
# 2003                                                NaN   28.0       NX
# 2004  Pr. indbygger, 2010-priser, kædede værdier, (1...  150.2        C
# 2004  Pr. indbygger, 2010-priser, kædede værdier, (1...   80.8        G
# 2004  Pr. indbygger, 2010-priser, kædede værdier, (1...   66.5        I
# 2004                                                NaN   24.3       NX
# 2005  Pr. indbygger, 2010-priser, kædede værdier, (1...  155.3        C
# 2005  Pr. indbygger, 2010-priser, kædede værdier, (1...   81.5        G
# 2005  Pr. indbygger, 2010-priser, kædede værdier, (1...   70.0        I
# 2005                                                NaN   21.9       NX
# 2006  Pr. indbygger, 2010-priser, kædede værdier, (1...  159.3        C
# 2006  Pr. indbygger, 2010-priser, kædede værdier, (1...   83.3        G
# 2006  Pr. indbygger, 2010-priser, kædede værdier, (1...   78.7        I
# 2006                                                NaN   19.4       NX
# 2007  Pr. indbygger, 2010-priser, kædede værdier, (1...  161.5        C
# 2007  Pr. indbygger, 2010-priser, kædede værdier, (1...   84.0        G
# 2007  Pr. indbygger, 2010-priser, kædede værdier, (1...   80.4        I
# 2007                                                NaN   16.8       NX
# 2008  Pr. indbygger, 2010-priser, kædede værdier, (1...  161.3        C
# 2008  Pr. indbygger, 2010-priser, kædede værdier, (1...   86.2        G
# ...                                                 ...    ...      ...
# 2011  Pr. indbygger, 2010-priser, kædede værdier, (1...   62.0        I
# 2011                                                NaN   23.9       NX
# 2012  Pr. indbygger, 2010-priser, kædede værdier, (1...  155.4        C
# 2012  Pr. indbygger, 2010-priser, kædede værdier, (1...   88.8        G
# 2012  Pr. indbygger, 2010-priser, kædede værdier, (1...   63.2        I
# 2012                                                NaN   21.7       NX
# 2013  Pr. indbygger, 2010-priser, kædede værdier, (1...  155.2        C
# 2013  Pr. indbygger, 2010-priser, kædede værdier, (1...   88.3        G
# 2013  Pr. indbygger, 2010-priser, kædede værdier, (1...   65.0        I
# 2013                                                NaN   22.2       NX
# 2014  Pr. indbygger, 2010-priser, kædede værdier, (1...  155.8        C
# 2014  Pr. indbygger, 2010-priser, kædede værdier, (1...   89.5        G
# 2014  Pr. indbygger, 2010-priser, kædede værdier, (1...   67.5        I
# 2014                                                NaN   21.5       NX
# 2015  Pr. indbygger, 2010-priser, kædede værdier, (1...  158.3        C
# 2015  Pr. indbygger, 2010-priser, kædede værdier, (1...   90.4        G
# 2015  Pr. indbygger, 2010-priser, kædede værdier, (1...   70.5        I
# 2015                                                NaN   20.6       NX
# 2016  Pr. indbygger, 2010-priser, kædede værdier, (1...  160.3        C
# 2016  Pr. indbygger, 2010-priser, kædede værdier, (1...   89.8        G
# 2016  Pr. indbygger, 2010-priser, kædede værdier, (1...   74.3        I
# 2016                                                NaN   20.6       NX
# 2017  Pr. indbygger, 2010-priser, kædede værdier, (1...  162.6        C
# 2017  Pr. indbygger, 2010-priser, kædede værdier, (1...   89.9        G
# 2017  Pr. indbygger, 2010-priser, kædede værdier, (1...   76.8        I
# 2017                                                NaN   21.2       NX
# 2018  Pr. indbygger, 2010-priser, kædede værdier, (1...  165.5        C
# 2018  Pr. indbygger, 2010-priser, kædede værdier, (1...   90.2        G
# 2018  Pr. indbygger, 2010-priser, kædede værdier, (1...   80.4        I
# 2018                                                NaN   17.5       NX
#
# [72 rows x 3 columns]

# %%
Y = pd.to_numeric(dollo_K.loc[:,:].value[dollo_K.loc[:,:].variable == 'C']) + pd.to_numeric(dollo_K.loc[:,:].value[dollo_K.loc[:,:].variable== 'G']) + pd.to_numeric(dollo_K.loc[:,:].value[dollo_K.loc[:,:].variable== 'I'])  + pd.to_numeric(dollo_K.loc[:,:].value[dollo_K.loc[:,:].variable== 'NX'])
Y.columns=['year','value']

# %%
Y = pd.DataFrame(data=Y)
Y['variable'] = 'Y'

# %% [markdown]
# To simplify creating of our following figures, we reset index for our Y1 value

# %%
dollo_K1 = dollo_K.reset_index()
Y1 = Y.reset_index()

nan3.set_index(['year'], inplace=True)
nan3.sort_index(inplace=True)
nan3=nan3.reset_index()
nan3["value"]=nan3["value"].str.replace(",",".").astype(float)

# %% [markdown]
# For the following figure, we will make two Y-axis

# %%
fig, ax = plt.subplots(figsize=(20,7))
dollo_K1.groupby(['year','variable']).sum()['value'].unstack().plot( ax=ax,  kind='bar', stacked = False)
nan3.groupby(['year','variable']).sum()['value'].plot(ax=ax,  secondary_y=True, color="r").set_ylabel("Percent")
ax.set_ylabel('1.000 DKK')
ax.set_title('Figure 2. GDP in chained values per capita and real GDP growth')
plt.show()

# %% [markdown]
# Figure 2 shows the development in the components of GDP on the left axis in 1000 Danish Kroner, while the real growth of GDP is shown in percent on the right axis.
#
# In this part, we will analyze the development in the Danish GDP and its componets in relation to business cycles.
# Before we begin our formal analysis, we will briefly describe the relevant business cycles in regard to Figure 2.
# Note the years 1994 - 2000 was a period with “boom”, however these years are not present in the figure.
# The period 2001 - 2003 is considered as a period with “recession” ith a average growthrate of 0.6% pro anno
# The period 2004 - 2007 is considered as a period with “boom” with a average growthrate of 2.4% pro anno.
# The period 2008 - 2015 is considered as a period with “recession” with a average growthrate of -0.1% pro anno.
# From 2016 and forward we do not have a clear definition of the annual growth rate, so we cannot with certain define the exact business cycle.
#
# The overall picture of the develepment in the compoments of GDP are:
# Private consumption: Is affect of the business cycles of the economy, in periods with "recession" people tend to spend less money, while the spend more money in periods with "booms", which is also clear from Figure 2.
# Investments: Are one of the most volatile components in GDP and highly affeced by business cycles, they story is the same as with Private Consumption, but the is a much clear relationship between investments and busines cycles.
# Goverment spending: Is not that very volatile. The purpose of goverment spending is to stabilize the economy in business cycles. The goverment tend to use more money in periods with "recession", and spend less money in periods with "booms"
# Netexport: Also highly corrolated with the business cycles. Note: when netexport is positive we sell more to foreign countries than we buy from them. When the netexport is negative we buy more from the foreign countries than we sell to them.
#
#
# In the next section we will make

# %%
samle1234= pd.concat([df_K, dollo])
samle1234=samle1234[samle1234.variable!="C"]
samle1234=samle1234[samle1234.variable!="G"]
samle1234=samle1234[samle1234.variable!="M"]
samle1234=samle1234[samle1234.variable!="I"]
samle1234=samle1234[samle1234.variable!="X"]
samle1234=samle1234[samle1234.variable!="NX"]
samle1234=samle1234.reset_index()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Create two bounded text box that allow only numbers between the min year (2001) and the max year (2018)

# %%
start_year = widgets.BoundedFloatText(
    value=samle1234.year.min(),
    min=samle1234.year.min(),
    max=samle1234.year.max(),
    step=1,
    description='Start Year:',
    disabled=False,
    color='black'
)
end_year = widgets.BoundedFloatText(
    value=samle1234.year.max(),
    min=samle1234.year.min(),
    max=samle1234.year.max(),
    step=1,
    description='End Year:',
    disabled=False,
    color='black'
)

# Make a dropdown to select the Area, or "All"
area = widgets.Dropdown(
    options=['All'] + list(samle1234['variable'].unique()),
    value='All',
    description='variable:',
)

def plotit(area, start_year, end_year):
    if start_year > end_year:
        print("You must select a start year that is prior to end year")
    else:
        df2 = samle1234.copy()
        if area != 'All':
            df2 = df2[df2.variable == area ]

        # Filter between min and max years (inclusive)
        df2 = df2[(df2.year >= start_year) & (df2.year <= end_year)]


        # Plot it (only if there's data to plot)
        if len(df2) > 0:
            df2.groupby(['year', 'variable']).sum()['value'].unstack().plot(kind='line', stacked=False, title="Area = {}".format(area))
            plt.show();
        else:
            print("No data to show for current selection")

# %%
interactive(plotit, area=area, start_year=start_year, end_year=end_year)
# Out:
# interactive(children=(Dropdown(description='variable:', options=('All', 'Y', 'Y_L'), value='All'), BoundedFloa…

# %% [markdown]
# # Creating Danish Phillips curve
#
# In the last section of our project, we will create 3 curves. One theoretical, one non-interactive scatterplot and one interactive.
#
# We begin by getting statistics for inflation in Denmark

# %%
pris119 = dst.get_data(table_id = 'PRIS119', variables={'TID':['*'], 'HOVED':['*']})
pris119.rename(columns = columns_dict, inplace = True)

# %%
infl = pd.DataFrame(data=pris119)
infl = infl[infl.Type !='Årsgennemsnit']
infl = infl[infl.value !='..']
infl["value"]=infl["value"].str.replace(",",".").astype(float)
print(infl)


AULAAR = dst.get_data(table_id = 'AULAAR', variables={'TID':['*']})
X = AULAAR["TID"]>1996
AULAAR1 = AULAAR[X]
AULAAR1.rename(columns = columns_dict, inplace = True)
# Out:
#     year         Type  value
# 3   1997  Årsstigning    2.0
# 5   1998  Årsstigning    1.3
# 7   1999  Årsstigning    2.0
# 9   2000  Årsstigning    2.7
# 11  2001  Årsstigning    2.3
# 13  2002  Årsstigning    2.4
# 15  2003  Årsstigning    1.9
# 17  2004  Årsstigning    0.9
# 19  2005  Årsstigning    1.7
# 21  2006  Årsstigning    1.8
# 23  2007  Årsstigning    1.7
# 25  2008  Årsstigning    3.6
# 27  2009  Årsstigning    1.0
# 29  2010  Årsstigning    2.2
# 31  2011  Årsstigning    2.7
# 33  2012  Årsstigning    2.4
# 35  2013  Årsstigning    0.5
# 37  2014  Årsstigning    0.4
# 39  2015  Årsstigning    0.2
# 41  2016  Årsstigning    0.0
# 43  2017  Årsstigning    1.1
# 45  2018  Årsstigning    0.7
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
AULAAR1 = pd.DataFrame(data=AULAAR1)
AULAAR1['value']=AULAAR1['value'].str.replace(',','.').astype(float)
print(AULAAR1)
# Out:
#     year    KØN                       Type  value
# 18  1997  I alt  Procent af arbejdsstyrken    7.3
# 19  1998  I alt  Procent af arbejdsstyrken    6.0
# 20  1999  I alt  Procent af arbejdsstyrken    5.2
# 21  2000  I alt  Procent af arbejdsstyrken    4.9
# 22  2001  I alt  Procent af arbejdsstyrken    4.7
# 23  2002  I alt  Procent af arbejdsstyrken    4.8
# 24  2003  I alt  Procent af arbejdsstyrken    5.8
# 25  2004  I alt  Procent af arbejdsstyrken    5.8
# 26  2005  I alt  Procent af arbejdsstyrken    5.1
# 27  2006  I alt  Procent af arbejdsstyrken    3.9
# 28  2007  I alt  Procent af arbejdsstyrken    2.7
# 29  2008  I alt  Procent af arbejdsstyrken    1.9
# 30  2009  I alt  Procent af arbejdsstyrken    3.6
# 31  2010  I alt  Procent af arbejdsstyrken    4.2
# 32  2011  I alt  Procent af arbejdsstyrken    4.0
# 33  2012  I alt  Procent af arbejdsstyrken    4.5
# 34  2013  I alt  Procent af arbejdsstyrken    4.4
# 35  2014  I alt  Procent af arbejdsstyrken    4.0
# 36  2015  I alt  Procent af arbejdsstyrken    3.8
# 37  2016  I alt  Procent af arbejdsstyrken    3.3
# 38  2017  I alt  Procent af arbejdsstyrken    3.3
# 39  2018  I alt  Procent af arbejdsstyrken    3.1

# %%
aaar= pd.DataFrame(data=AULAAR1["year"])
aaar.set_index(['year'], inplace=True)
aaar.sort_index(inplace=True)
aaar = aaar.reset_index()

# %%
fit = np.polyfit(AULAAR1['value'], infl['value'], 1)
fit_fn = np.poly1d(fit)
plt.subplot()
#plt.plot(AULAAR1['value'], infl['value'], 'C3', zorder=1, lw=1)
plt.scatter(AULAAR1['value'], infl['value'], label='year')
plt.title('Figure 3: Danish Phillips curve')
plt.xlabel('Unemployment %')
plt.ylabel('Inflation %')

plt.plot(AULAAR1['value'], infl['value'], 'yo', AULAAR1['value'], fit_fn(AULAAR1['value']), '--k')

plt.show()
